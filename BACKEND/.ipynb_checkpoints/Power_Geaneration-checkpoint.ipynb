# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import xgboost as xgb
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv(r"C:\Users\Dell\Music\POWER_GENERATION\DATASET\Solar Power Plant Data.csv")
df
# Out:
#         Date-Hour(NMT)  WindSpeed  Sunshine  AirPressure  Radiation  \
# 0     01.01.2017-00:00        0.6         0       1003.8       -7.4
# 1     01.01.2017-01:00        1.7         0       1003.5       -7.4
# 2     01.01.2017-02:00        0.6         0       1003.4       -6.7
# 3     01.01.2017-03:00        2.4         0       1003.3       -7.2
# 4     01.01.2017-04:00        4.0         0       1003.1       -6.3
# ...                ...        ...       ...          ...        ...
# 8755  31.12.2017-19:00        4.1         0        988.2       -4.8
# 8756  31.12.2017-20:00        2.1         0        987.3       -5.0
# 8757  31.12.2017-21:00        1.8         0        986.7       -5.3
# 8758  31.12.2017-22:00        2.2         0        986.0       -5.4
# 8759  31.12.2017-23:00        2.4         0        985.6       -5.9
#
#       AirTemperature  RelativeAirHumidity  SystemProduction
# 0                0.1                   97               0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date-Hour(NMT)       8760 non-null   object
#  1   WindSpeed            8760 non-null   float64
#  2   Sunshine             8760 non-null   int64
#  3   AirPressure          8760 non-null   float64
#  4   Radiation            8760 non-null   float64
#  5   AirTemperature       8760 non-null   float64
#  6   RelativeAirHumidity  8760 non-null   int64
#  7   SystemProduction     8760 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 547.6+ KB

# %%
df.describe()
# Out:
#          WindSpeed     Sunshine  AirPressure    Radiation  AirTemperature  \
# count  8760.000000  8760.000000  8760.000000  8760.000000     8760.000000
# mean      2.639823    11.180479  1010.361781    97.538493        6.978893
# std       1.628754    21.171295    12.793971   182.336029        7.604266
# min       0.000000     0.000000   965.900000    -9.300000      -12.400000
# 25%       1.400000     0.000000  1002.800000    -6.200000        0.500000
# 50%       2.300000     0.000000  1011.000000    -1.400000        6.400000
# 75%       3.600000     7.000000  1018.200000   115.600000       13.400000
# max      10.900000    60.000000  1047.300000   899.700000       27.100000
#
#        RelativeAirHumidity  SystemProduction
# count          8760.000000       8760.000000
# mean             76.719406        684.746071
# std              19.278996       1487.454665
# min              13.000000          0.000000
# 25%              64.000000          0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Date-Hour(NMT)         0
# WindSpeed              0
# Sunshine               0
# AirPressure            0
# Radiation              0
# AirTemperature         0
# RelativeAirHumidity    0
# SystemProduction       0
# dtype: int64

# %%
# Convert Date-Hour to datetime format
df['Date-Hour(NMT)'] = pd.to_datetime(df['Date-Hour(NMT)'])
df
# Out:
#           Date-Hour(NMT)  WindSpeed  Sunshine  AirPressure  Radiation  \
# 0    2017-01-01 00:00:00        0.6         0       1003.8       -7.4
# 1    2017-01-01 01:00:00        1.7         0       1003.5       -7.4
# 2    2017-01-01 02:00:00        0.6         0       1003.4       -6.7
# 3    2017-01-01 03:00:00        2.4         0       1003.3       -7.2
# 4    2017-01-01 04:00:00        4.0         0       1003.1       -6.3
# ...                  ...        ...       ...          ...        ...
# 8755 2017-12-31 19:00:00        4.1         0        988.2       -4.8
# 8756 2017-12-31 20:00:00        2.1         0        987.3       -5.0
# 8757 2017-12-31 21:00:00        1.8         0        986.7       -5.3
# 8758 2017-12-31 22:00:00        2.2         0        986.0       -5.4
# 8759 2017-12-31 23:00:00        2.4         0        985.6       -5.9
#
#       AirTemperature  RelativeAirHumidity  SystemProduction
# 0                0.1                   97               0.0
# ...

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
plt.plot(df['Date-Hour(NMT)'], df['SystemProduction'], label='Energy Production', color='blue')
plt.xlabel("Date-Hour")
plt.ylabel("System Production")
plt.title("Time Series of Energy Production")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
df['Date-Hour(NMT)'] = pd.to_datetime(df['Date-Hour(NMT)'])

# Extract time-based features
df['Hour'] = df['Date-Hour(NMT)'].dt.hour
df['DayOfWeek'] = df['Date-Hour(NMT)'].dt.dayofweek
df['Month'] = df['Date-Hour(NMT)'].dt.month
df['DayOfYear'] = df['Date-Hour(NMT)'].dt.dayofyear  # Optional

# %%
sns.pairplot(df, vars=['WindSpeed', 'Sunshine', 'AirPressure', 'Radiation', 'AirTemperature', 'RelativeAirHumidity', 'SystemProduction'])
plt.show()

# %%
df
# Out:
#           Date-Hour(NMT)  WindSpeed  Sunshine  AirPressure  Radiation  \
# 0    2017-01-01 00:00:00        0.6         0       1003.8       -7.4
# 1    2017-01-01 01:00:00        1.7         0       1003.5       -7.4
# 2    2017-01-01 02:00:00        0.6         0       1003.4       -6.7
# 3    2017-01-01 03:00:00        2.4         0       1003.3       -7.2
# 4    2017-01-01 04:00:00        4.0         0       1003.1       -6.3
# ...                  ...        ...       ...          ...        ...
# 8755 2017-12-31 19:00:00        4.1         0        988.2       -4.8
# 8756 2017-12-31 20:00:00        2.1         0        987.3       -5.0
# 8757 2017-12-31 21:00:00        1.8         0        986.7       -5.3
# 8758 2017-12-31 22:00:00        2.2         0        986.0       -5.4
# 8759 2017-12-31 23:00:00        2.4         0        985.6       -5.9
#
#       AirTemperature  RelativeAirHumidity  SystemProduction  Hour  DayOfWeek  \
# ...

# %%
X = df.drop(columns=['SystemProduction', 'Date-Hour(NMT)'])
y = df['SystemProduction']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# Train XGBoost Model
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, learning_rate=0.1, max_depth=6, random_state=42)
xgb_model.fit(X_train, y_train)

# Predictions
y_pred = xgb_model.predict(X_test)

# Evaluation Metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R2): {r2}")
# Out:
# Mean Absolute Error (MAE): 84.29816479436785
# Mean Squared Error (MSE): 58912.598007539076
# Root Mean Squared Error (RMSE): 242.71917519540781
# R-squared (R2): 0.38889940460136774

# %%
# Visualizing Predictions
plt.figure(figsize=(12,6))
plt.plot(y_test.values, label="Actual", color='blue')
plt.plot(y_pred, label="Predicted", color='red')
plt.xlabel("Samples")
plt.ylabel("System Production")
plt.title("Actual vs Predicted Energy Production - XGBoost")
plt.legend()
plt.show()

# %%
# !pip install lightgbm
# Out:
# ...
#      ---------------------------------------- 1.5/1.5 MB 2.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.9/14.9 MB 3.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# tensorflow 2.19.0 requires ml-dtypes<1.0.0,>=0.5.1, but you have ml-dtypes 0.4.1 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 1.24.4 which is incompatible.
# tensorflow 2.19.0 requires tensorboard~=2.19.0, but you have tensorboard 2.18.0 which is incompatible.
# tensorflow-intel 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.24.4 which is incompatible.
# ...

# %%
# Convert categorical features to numeric (if any exist)
X_train = X_train.apply(pd.to_numeric, errors='coerce')
X_test = X_test.apply(pd.to_numeric, errors='coerce')

# Ensure target variable is numeric
y_train = pd.to_numeric(y_train, errors='coerce')
y_test = pd.to_numeric(y_test, errors='coerce')

# Check for NaN values after conversion
X_train.fillna(0, inplace=True)
X_test.fillna(0, inplace=True)
y_train.fillna(0, inplace=True)
y_test.fillna(0, inplace=True)

# %%
# !pip install --upgrade numpy lightgbm
# Out:
# ...
#   Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl (15.9 MB)
# ...

# %%
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Initialize LightGBM model
lgb_model = lgb.LGBMRegressor(
    n_estimators=1000, 
    learning_rate=0.05, 
    max_depth=7, 
    num_leaves=31, 
    subsample=0.8, 
    colsample_bytree=0.8, 
    random_state=42
)

# Train the model
lgb_model.fit(X_train, y_train)

# Predictions
y_pred = lgb_model.predict(X_test)

# Evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

# Print results
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R2): {r2}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12228\3139936224.py in <module>
# ----> 1 import lightgbm as lgb
#       2 from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
#       3
#       4 # Initialize LightGBM model
#       5 lgb_model = lgb.LGBMRegressor(
#
# ~\anaconda3\lib\site-packages\lightgbm\__init__.py in <module>
#       9 # .basic is intentionally loaded as early as possible, to dlopen() lib_lightgbm.{dll,dylib,so}
#      10 # and its dependencies as early as possible
# ---> 11 from .basic import Booster, Dataset, Sequence, register_logger
#      12 from .callback import EarlyStopException, early_stopping, log_evaluation, record_evaluation, reset_parameter
#      13 from .engine import CVBooster, cv, train
#
# ~\anaconda3\lib\site-packages\lightgbm\basic.py in <module>
#      27 import scipy.sparse
# ...

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Initialize LightGBM model
lgb_model = lgb.LGBMRegressor(n_estimators=1000, learning_rate=0.05, max_depth=7, random_state=42)

# Train the model
lgb_model.fit(X_train, y_train)

# Predictions
y_pred = lgb_model.predict(X_test)

# Evaluation metrics
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred, squared=False))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12228\1713369340.py in <module>
# ----> 1 import lightgbm as lgb
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
#       4
#       5 # Initialize LightGBM model
#
# ~\anaconda3\lib\site-packages\lightgbm\__init__.py in <module>
#       9 # .basic is intentionally loaded as early as possible, to dlopen() lib_lightgbm.{dll,dylib,so}
#      10 # and its dependencies as early as possible
# ---> 11 from .basic import Booster, Dataset, Sequence, register_logger
#      12 from .callback import EarlyStopException, early_stopping, log_evaluation, record_evaluation, reset_parameter
#      13 from .engine import CVBooster, cv, train
#
# ~\anaconda3\lib\site-packages\lightgbm\basic.py in <module>
# ...

# %%
df.sort_values('Date', inplace=True)

# %%
df.isnull().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Market Cap    0
# dtype: int64

# %%
df['Volume'] = df['Volume'].str.replace(',', '')
df['Volume'] = pd.to_numeric(df['Volume'], errors='coerce')  # Convert to numeric, invalid parsing will be set as NaN
df['Volume'] = df['Volume'].fillna(0)  # Replace NaN with 0 (or any suitable imputation strategy)

# %%
df['Market Cap'] = df['Market Cap'].str.replace(',', '').astype(float)

# %%
df
# Out:
#            Date     Open     High      Low    Close        Volume  \
# 1555 2013-04-28   135.30   135.98   132.10   134.21  0.000000e+00
# 1554 2013-04-29   134.44   147.49   134.00   144.54  0.000000e+00
# 1553 2013-04-30   144.00   146.93   134.05   139.00  0.000000e+00
# 1552 2013-05-01   139.00   139.89   107.72   116.99  0.000000e+00
# 1551 2013-05-02   116.38   125.60    92.28   105.21  0.000000e+00
# ...         ...      ...      ...      ...      ...           ...
# 4    2017-07-27  2538.71  2693.32  2529.34  2671.78  7.891040e+08
# 3    2017-07-28  2679.73  2897.45  2679.73  2809.01  1.380100e+09
# 2    2017-07-29  2807.02  2808.76  2692.80  2726.45  8.037460e+08
# 1    2017-07-30  2724.39  2758.53  2644.85  2757.18  7.059430e+08
# 0    2017-07-31  2763.24  2889.62  2720.61  2875.34  8.605750e+08
#
#         Market Cap
# 1555  1.500520e+09
# 1554  1.491160e+09
# 1553  1.597780e+09
# 1552  1.542820e+09
# 1551  1.292190e+09
# ...            ...
# 4     4.181650e+10
# ...

# %%
## 2. Exploratory Data Analysis (EDA)
plt.figure(figsize=(14,6))
plt.plot(df['Date'], df['Close'], label='Bitcoin Price')
plt.title('Bitcoin Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.legend()
plt.show()

# %%
df.corr()
# Out:
#                 Date      Open      High       Low     Close    Volume  \
# Date        1.000000  0.593046  0.585287  0.603414  0.593531  0.520976
# Open        0.593046  1.000000  0.998561  0.998157  0.997514  0.867416
# High        0.585287  0.998561  1.000000  0.997320  0.998596  0.876981
# Low         0.603414  0.998157  0.997320  1.000000  0.998755  0.861368
# Close       0.593531  0.997514  0.998596  0.998755  1.000000  0.869093
# Volume      0.520976  0.867416  0.876981  0.861368  0.869093  1.000000
# Market Cap  0.644175  0.995153  0.993298  0.994575  0.993041  0.884452
#
#             Market Cap
# Date          0.644175
# Open          0.995153
# High          0.993298
# Low           0.994575
# Close         0.993041
# Volume        0.884452
# Market Cap    1.000000

# %%
# Correlation Heatmap
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
corr = df.corr()
# Change np.bool to bool
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(20, 20))
cmap = sns.diverging_palette(250, 25, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=None, center=0,square=True, annot=True, linewidths=.5, cbar_kws={"shrink": .9})
# Out:
# <Axes: >

# %%
for column in df.columns:
    if column != 'Close':
        plt.figure(figsize=(8, 5))
        sns.scatterplot(x='Close', y=column, data=df)
        plt.xlabel('Close')
        plt.ylabel(column)
        plt.title(f'Scatter plot of Close vs {column}')
        plt.show()

# %%
sns.pairplot(df[['Open', 'High', 'Low', 'Close']])
plt.show()

# %%
X = df.drop(columns=['Date', 'Close'])
y = df['Close']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, learning_rate=0.1, max_depth=5)
xgb_model.fit(X_train, y_train)
y_pred_xgb = xgb_model.predict(X_test)

# XGBoost Metrics
print(f'XGBoost R2 Score: {r2_score(y_test, y_pred_xgb)}')
print(f'XGBoost MAE: {mean_absolute_error(y_test, y_pred_xgb)}')
print(f'XGBoost MSE: {mean_squared_error(y_test, y_pred_xgb)}')
print(f'XGBoost RMSE: {np.sqrt(mean_squared_error(y_test, y_pred_xgb))}')

plt.figure(figsize=(14,7))
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred_xgb, label='XGBoost Prediction')
plt.title('XGBoost Predicted vs Actual')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# XGBoost R2 Score: -0.03026374730955106
# XGBoost MAE: 403.19060522617445
# XGBoost MSE: 519294.69307624374
# XGBoost RMSE: 720.6210467896727

# %%
## 2. LSTM Model
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[['Close']])
X_lstm = np.array([scaled_data[i:i+30] for i in range(len(scaled_data)-30)])
y_lstm = np.array([scaled_data[i+30] for i in range(len(scaled_data)-30)])
X_train_lstm, X_test_lstm = X_lstm[:-200], X_lstm[-200:]
y_train_lstm, y_test_lstm = y_lstm[:-200], y_lstm[-200:]

lstm_model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(30, 1)),
    Dropout(0.3),
    LSTM(64),
    Dense(1)
])
lstm_model.compile(optimizer='adam', loss='mean_squared_error')

history = lstm_model.fit(X_train_lstm, y_train_lstm, epochs=50, batch_size=32, validation_data=(X_test_lstm, y_test_lstm), verbose=1)

# Display Performance Metrics
print(f'LSTM R2 Score: {r2_score(y_actual, y_pred_lstm)}')
print(f'LSTM MAE: {mean_absolute_error(y_actual, y_pred_lstm)}')
print(f'LSTM MSE: {mean_squared_error(y_actual, y_pred_lstm)}')
print(f'LSTM RMSE: {np.sqrt(mean_squared_error(y_actual, y_pred_lstm))}')
# Out:
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.3049e-04 - val_loss: 0.0059
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 3.0120e-04 - val_loss: 0.0039
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 2.7952e-04 - val_loss: 0.0079
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 2.2238e-04 - val_loss: 0.0042
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 2.0051e-04 - val_loss: 0.0054
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 1.8525e-04 - val_loss: 0.0054
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 2.0046e-04 - val_loss: 0.0098
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 1.4938e-04 - val_loss: 0.0118
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 2.1657e-04 - val_loss: 0.0065
# Epoch 11/50
# ...

# %%
# Evaluate and Plot Actual vs. Predicted
y_pred_lstm = scaler.inverse_transform(lstm_model.predict(X_test_lstm))
y_actual = scaler.inverse_transform(y_test_lstm)

plt.figure(figsize=(12,6))
plt.plot(y_actual, label='Actual Prices')
plt.plot(y_pred_lstm, label='Predicted Prices', linestyle='dashed')
plt.title('LSTM Actual vs Predicted Bitcoin Prices')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step

# %%
## 5. Model Comparison
plt.figure(figsize=(14,7))
plt.plot(y_test_lstm, label='Actual')
plt.plot(scaler.inverse_transform(lstm_model.predict(X_test_lstm)), label='LSTM Prediction')
plt.plot(y_pred_xgb[-200:], label='XGBoost Prediction')
plt.title('XGBoost vs LSTM Predictions')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
df.head(8)
# Out:
#            Date     Open     High      Low    Close         Volume  \
# 0  Jul 31, 2017  2763.24  2889.62  2720.61  2875.34    860,575,000
# 1  Jul 30, 2017  2724.39  2758.53  2644.85  2757.18    705,943,000
# 2  Jul 29, 2017  2807.02  2808.76  2692.80  2726.45    803,746,000
# 3  Jul 28, 2017  2679.73  2897.45  2679.73  2809.01  1,380,100,000
# 4  Jul 27, 2017  2538.71  2693.32  2529.34  2671.78    789,104,000
# 5  Jul 26, 2017  2577.77  2610.76  2450.80  2529.45    937,404,000
# 6  Jul 25, 2017  2757.50  2768.08  2480.96  2576.48  1,460,090,000
# 7  Jul 24, 2017  2732.70  2777.26  2699.19  2754.86    866,474,000
#
#        Market Cap
# 0  45,535,800,000
# 1  44,890,700,000
# 2  46,246,700,000
# 3  44,144,400,000
# 4  41,816,500,000
# 5  42,455,000,000
# 6  45,410,100,000
# 7  44,995,600,000
